# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\mandl\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
a=pd.read_csv('cars (2).csv')

# %%
a
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
a.replace("?",np.nan,inplace=True)

# %%
a.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
a['normalized-losses'].astype(float)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
a['normalized-losses']=pd.to_numeric(a['normalized-losses'])

# %%
a['normalized-losses'].fillna(a['normalized-losses'].mean(),inplace=True)
# Out:
# C:\Users\mandl\AppData\Local\Temp\ipykernel_17568\2106091521.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['normalized-losses'].fillna(a['normalized-losses'].mean(),inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(a['make'])
a['make']=le.transform(a['make'])

# %%
a
# Out:
#      symboling  normalized-losses  make fuel-type   body-style drive-wheels  \
# 0            3              122.0     0       gas  convertible          rwd
# 1            3              122.0     0       gas  convertible          rwd
# 2            1              122.0     0       gas    hatchback          rwd
# 3            2              164.0     1       gas        sedan          fwd
# 4            2              164.0     1       gas        sedan          4wd
# ..         ...                ...   ...       ...          ...          ...
# 200         -1               95.0    21       gas        sedan          rwd
# 201         -1               95.0    21       gas        sedan          rwd
# 202         -1               95.0    21       gas        sedan          rwd
# 203         -1               95.0    21    diesel        sedan          rwd
# 204         -1               95.0    21       gas        sedan          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 0             front   64.1    48.8        dohc          130        111
# 1             front   64.1    48.8        dohc          130        111
# 2             front   65.5    52.4        ohcv          152        154
# 3             front   66.2    54.3         ohc          109        102
# 4             front   66.4    54.3         ohc          136        115
# ..              ...    ...     ...         ...          ...        ...
# 200           front   68.9    55.5         ohc          141        114
# 201           front   68.8    55.5         ohc          141        160
# 202           front   68.9    55.5        ohcv          173        134
# 203           front   68.9    55.5         ohc          145        106
# 204           front   68.9    55.5         ohc          141        114
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 15 columns]

# %%
le.fit(a['fuel-type'])
a['fuel-type']=le.transform(a['fuel-type'])

# %%
le.fit(a['body-style'])
a['body-style']=le.transform(a['body-style'])

# %%
le.fit(a['drive-wheels'])
a['drive-wheels']=le.transform(a['drive-wheels'])

# %%
le.fit(a['engine-location'])
a['engine-location']=le.transform(a['engine-location'])

# %%
le.fit(a['engine-type'])
a['engine-type']=le.transform(a['engine-type'])

# %%
a
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0     0          1           0             2
# 1            3              122.0     0          1           0             2
# 2            1              122.0     0          1           2             2
# 3            2              164.0     1          1           3             1
# 4            2              164.0     1          1           3             0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0    21          1           3             2
# 201         -1               95.0    21          1           3             2
# 202         -1               95.0    21          1           3             2
# 203         -1               95.0    21          0           3             2
# 204         -1               95.0    21          1           3             2
#
#      engine-location  width  height  engine-type  engine-size horsepower  \
# 0                  0   64.1    48.8            0          130        111
# 1                  0   64.1    48.8            0          130        111
# 2                  0   65.5    52.4            5          152        154
# 3                  0   66.2    54.3            3          109        102
# 4                  0   66.4    54.3            3          136        115
# ..               ...    ...     ...          ...          ...        ...
# 200                0   68.9    55.5            3          141        114
# 201                0   68.8    55.5            3          141        160
# 202                0   68.9    55.5            5          173        134
# 203                0   68.9    55.5            3          145        106
# 204                0   68.9    55.5            3          141        114
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 15 columns]

# %%
a.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                   int32
# fuel-type              int32
# body-style             int32
# drive-wheels           int32
# engine-location        int32
# width                float64
# height               float64
# engine-type            int32
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
a['horsepower']=a['horsepower'].astype(float)

# %%
a.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                   int32
# fuel-type              int32
# body-style             int32
# drive-wheels           int32
# engine-location        int32
# width                float64
# height               float64
# engine-type            int32
# engine-size            int64
# horsepower           float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
x=a.iloc[:,:-1]

# %%
x
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0     0          1           0             2
# 1            3              122.0     0          1           0             2
# 2            1              122.0     0          1           2             2
# 3            2              164.0     1          1           3             1
# 4            2              164.0     1          1           3             0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0    21          1           3             2
# 201         -1               95.0    21          1           3             2
# 202         -1               95.0    21          1           3             2
# 203         -1               95.0    21          0           3             2
# 204         -1               95.0    21          1           3             2
#
#      engine-location  width  height  engine-type  engine-size  horsepower  \
# 0                  0   64.1    48.8            0          130       111.0
# 1                  0   64.1    48.8            0          130       111.0
# 2                  0   65.5    52.4            5          152       154.0
# 3                  0   66.2    54.3            3          109       102.0
# 4                  0   66.4    54.3            3          136       115.0
# ..               ...    ...     ...          ...          ...         ...
# 200                0   68.9    55.5            3          141       114.0
# 201                0   68.8    55.5            3          141       160.0
# 202                0   68.9    55.5            5          173       134.0
# 203                0   68.9    55.5            3          145       106.0
# 204                0   68.9    55.5            3          141       114.0
#
#      city-mpg  highway-mpg
# 0          21           27
# 1          21           27
# 2          19           26
# 3          24           30
# 4          18           22
# ..        ...          ...
# 200        23           28
# 201        19           25
# 202        18           23
# 203        26           27
# 204        19           25
#
# [205 rows x 14 columns]

# %%
y=a.iloc[:,-1]

# %%
y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import Ridge

# %%
a.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
a['horsepower'].head()
# Out:
# 0    111.0
# 1    111.0
# 2    154.0
# 3    102.0
# 4    115.0
# Name: horsepower, dtype: float64

# %%
a['horsepower'].fillna(a['horsepower'].mean(),inplace=True)
# Out:
# C:\Users\mandl\AppData\Local\Temp\ipykernel_17568\644990825.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['horsepower'].fillna(a['horsepower'].mean(),inplace=True)

# %%
a.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
x=a.iloc[:,:-1]
y=a.iloc[:,-1]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import Ridge

# %%
ridge=Ridge(alpha=0.001)
ridge.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=0.001)

# %%
ypred=ridge.predict(xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred)
# Out:
# 0.7531054934806087

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso(alpha=0.001)

# %%
lasso.fit(xtrain,ytrain)
# Out:
# Lasso(alpha=0.001)

# %%
ypred1=lasso.predict(xtest)

# %%
r2_score(ytest,ypred1)
# Out:
# 0.7531088628006977
