# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\mandl\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
a=pd.read_csv('HeartDisease.csv')

# %%
a
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0     63       1           3       145         233                    1
# 1     37       1           2       130         250                    0
# 2     41       0           1       130         204                    0
# 3     56       1           1       120         236                    0
# 4     57       0           0       120         354                    0
# ..   ...     ...         ...       ...         ...                  ...
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# ...

# %%
a.shape
# Out:
# (303, 14)

# %%
a.tail()
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# 298         1      123            1       0.2      1   0            3       0
# 299         1      132            0       1.2      1   0            3       0
# 300         1      141            0       3.4      1   2            3       0
# 301         1      115            1       1.2      1   1            3       0
# 302         0      174            0       0.0      1   1            2       0

# %%
a.head()
# Out:
#    age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0   63       1           3       145         233                    1
# 1   37       1           2       130         250                    0
# 2   41       0           1       130         204                    0
# 3   56       1           1       120         236                    0
# 4   57       0           0       120         354                    0
#
#    rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# 0         0      150            0       2.3      0   0            1       1
# 1         1      187            0       3.5      0   0            2       1
# 2         0      172            0       1.4      2   0            2       1
# 3         1      178            0       0.8      2   0            2       1
# 4         1      163            1       0.6      2   0            2       1

# %%
a.isnull().sum()
# Out:
# age                    0
# gender                 0
# chest_pain             0
# rest_bps               0
# cholestrol             0
# fasting_blood_sugar    0
# rest_ecg               0
# thalach                0
# exer_angina            0
# old_peak               0
# slope                  0
# ca                     0
# thalassemia            0
# target                 0
# dtype: int64

# %%
x=a.iloc[:,:-1]
y=a.iloc[:,-1]

# %%
x
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0     63       1           3       145         233                    1
# 1     37       1           2       130         250                    0
# 2     41       0           1       130         204                    0
# 3     56       1           1       120         236                    0
# 4     57       0           0       120         354                    0
# ..   ...     ...         ...       ...         ...                  ...
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(criterion='entropy',random_state=42,max_depth=10,min_samples_leaf=8)

# %%
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=8,
#                        random_state=42)

# %%
ypred=clf.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(ytest,ypred)
score
# Out:
# 0.8524590163934426

# %%
print("score is : ",score*100)
# Out:
# score is :  85.24590163934425

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf1=RandomForestClassifier(n_estimators=100)
clf1.fit(xtrain,ytrain)
ypred1=clf1.predict(xtest)

# %%
score1=accuracy_score(ytest,ypred1)
score1
# Out:
# 0.8688524590163934

# %%
print("score is : ",score1*100)
# Out:
# score is :  86.88524590163934
